# %% [markdown]
# # Intro to Machine Learning
#
# ## Toolkit Exercise
#
# - Daniel Attali 328780879

# %% [markdown]
# ### Q-1

# %% [markdown]
# Basic file manipulation and Python env

# %%
import numpy as numpy
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
# global const
DATA_DIR_PATH = "../data/"

# %% [markdown]
# We will do the same analysis on a new file

# %%
data_path = os.path.join(DATA_DIR_PATH, "Iris_Data.csv")
data = pd.read_csv(data_path)

# %% [markdown]
# DataFrame manipulation

# %%
# print the shape of the data + attribute names + the dtype of each
print(f"Data shape: {data.shape}")
print(f"Data columns: {data.columns.tolist()}")
print(f"Data types:\n{data.dtypes}")
# Out:
# Data shape: (150, 5)
# Data columns: ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
# Data types:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
# show the first 10 rows of the dataset
data.head(10)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa
# 5           5.4          3.9           1.7          0.4  Iris-setosa
# 6           4.6          3.4           1.4          0.3  Iris-setosa
# 7           5.0          3.4           1.5          0.2  Iris-setosa
# 8           4.4          2.9           1.4          0.2  Iris-setosa
# 9           4.9          3.1           1.5          0.1  Iris-setosa

# %%
# print the summary statistics for each feature
print(f"Summary statistics:\n{data.describe()}")
# Out:
# Summary statistics:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# Matplotlib manipulation

# %%
# load an display an image using matplotlib
img_path = os.path.join(DATA_DIR_PATH, "iris.jpeg")

import matplotlib.image as mpimg

test_img = mpimg.imread(img_path)
plt.figure(figsize=(5, 5))
plt.imshow(test_img)
plt.axis("off")
plt.show()

# %%
# show the number of entries
print(f"Number of entries: {data.shape[0]}")
# Out:
# Number of entries: 150

# %%
# get the list of column names

print(f"Attributes")
for col in data.columns:
    print(f" - {col}")
# Out:
# Attributes
#  - sepal_length
#  - sepal_width
#  - petal_length
#  - petal_width
#  - species

# %% [markdown]
# Seaborn plots

# %%
# plot a matrix of attributes vs attributes
# meaning sepal_length vs sepal_width etc

import seaborn as sns

sns.pairplot(data, hue="species", height=2.5)

# %% [markdown]
# ### Q-2

# %% [markdown]
# String manipulation + Attribute rename

# %%
# string manipulation

# rename the species attributes to have I- prefix instead of Iris-

data['species'] = data['species'].str.replace("Iris-", "I-")

# show the updated DataFrame
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width   species
# 0           5.1          3.5           1.4          0.2  I-setosa
# 1           4.9          3.0           1.4          0.2  I-setosa
# 2           4.7          3.2           1.3          0.2  I-setosa
# 3           4.6          3.1           1.5          0.2  I-setosa
# 4           5.0          3.6           1.4          0.2  I-setosa

# %% [markdown]
# ### Q-3

# %% [markdown]
# Data analysis

# %%
# get the number of each species present meaning bins of species

species_counts = data['species'].value_counts()

# display the results
for species, count in species_counts.items():
    print(f" - {species}: {count}")
# Out:
#  - I-setosa: 50
#  - I-versicolor: 50
#  - I-virginica: 50

# %%
# get the mean, median, ranges, min, max etc of each numeric attribute


for col in data.select_dtypes(include=['float64', 'int64']).columns:
    print(f"Attribute: {col}")
    print(f" - Mean: {data[col].mean():.2f}")
    print(f" - Median: {data[col].median()}")
    print(f" - Min: {data[col].min()}")
    print(f" - Max: {data[col].max()}")
    print(f" - Range: {data[col].max() - data[col].min():.2f}")
    print()
# Out:
# Attribute: sepal_length
#  - Mean: 5.84
#  - Median: 5.8
#  - Min: 4.3
#  - Max: 7.9
#  - Range: 3.60
#
# Attribute: sepal_width
#  - Mean: 3.05
#  - Median: 3.0
#  - Min: 2.0
#  - Max: 4.4
#  - Range: 2.40
#
# Attribute: petal_length
#  - Mean: 3.76
#  - Median: 4.35
#  - Min: 1.0
#  - Max: 6.9
#  - Range: 5.90
#
# Attribute: petal_width
#  - Mean: 1.20
#  - Median: 1.3
#  - Min: 0.1
#  - Max: 2.5
#  - Range: 2.40

# %%
# use describe 
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Q-4

# %% [markdown]
# Groupby manipulation

# %%
# calculate the the mean, median grouped by species

# use groupby

data.groupby('species').mean()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# species
# I-setosa             5.006        3.418         1.464        0.244
# I-versicolor         5.936        2.770         4.260        1.326
# I-virginica          6.588        2.974         5.552        2.026

# %%
data.groupby('species').median()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# species
# I-setosa               5.0          3.4          1.50          0.2
# I-versicolor           5.9          2.8          4.35          1.3
# I-virginica            6.5          3.0          5.55          2.0

# %%
# show both measures in one table

data.groupby('species').agg(['mean', 'median'])
# Out:
#              sepal_length        sepal_width        petal_length         \
#                      mean median        mean median         mean median
# species
# I-setosa            5.006    5.0       3.418    3.4        1.464   1.50
# I-versicolor        5.936    5.9       2.770    2.8        4.260   4.35
# I-virginica         6.588    6.5       2.974    3.0        5.552   5.55
#
#              petal_width
#                     mean median
# species
# I-setosa           0.244    0.2
# I-versicolor       1.326    1.3
# I-virginica        2.026    2.0

# %% [markdown]
# ### Q-5

# %% [markdown]
# Scatter plot

# %%
# scatter plot of sepal length vs sepal width
# %matplotlib inline
ax = plt.axes()

ax.scatter(data['sepal_length'], data['sepal_width'])

ax.set(xlabel='Sepal Length', ylabel='Sepal Width', title='Sepal Length vs Sepal Width')

# show the plot
# Out:
# [Text(0.5, 0, 'Sepal Length'),
#  Text(0, 0.5, 'Sepal Width'),
#  Text(0.5, 1.0, 'Sepal Length vs Sepal Width')]

# %% [markdown]
# ## Classification

# %%
filepath = os.path.join(DATA_DIR_PATH + 'iris_classification.png')
testim = mpimg.imread(filepath)
plt.figure(figsize=(10, 8), dpi=80)
plt.imshow(testim)

# %% [markdown]
# ## Regression

# %%
filepath = os.path.join(DATA_DIR_PATH + 'iris_regression.png')
testim = mpimg.imread(filepath)
plt.figure(figsize=(10, 8), dpi=80)
plt.imshow(testim)

# %% [markdown]
# ## Clustering

# %%
filepath = os.path.join(DATA_DIR_PATH + 'iris_clustering.jpg')
testim = mpimg.imread(filepath)
plt.figure(figsize=(10, 8), dpi=80)
plt.imshow(testim)

# %% [markdown]
# ### Q-6

# %% [markdown]
# Histogram & Bins

# %%
# Make a histogram of any one of the features, label axes and title

data['sepal_length'].hist(bins=20)

plt.xlabel('Sepal Length')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Length')

plt.show()

# %% [markdown]
# ### Q-7

# %%
# create histogram of all the attributes in one graph overlapping with different colors

data.plot.hist(alpha=0.5, bins=20, figsize=(15, 10), subplots=True, layout=(4, 4), sharex=False, sharey=False)
# Out:
# array([[<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>],
#        [<Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>,
#         <Axes: ylabel='Frequency'>, <Axes: ylabel='Frequency'>]],
#       dtype=object)

# %%
# create histogram of all the attributes in one graph
# not overlapping but one figure for each

data.plot.hist(alpha=0.5, bins=20, figsize=(15, 10))
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Q-8

# %% [markdown]
# Boxplot

# %%
plot_data = (data.set_index('species')
             .stack()
             .to_frame()
             .reset_index()
             .rename(columns={0: 'size', 'level_1': 'measurement'})
)

plot_data.head()
# Out:
#     species   measurement  size
# 0  I-setosa  sepal_length   5.1
# 1  I-setosa   sepal_width   3.5
# 2  I-setosa  petal_length   1.4
# 3  I-setosa   petal_width   0.2
# 4  I-setosa  sepal_length   4.9

# %%
# using pandas make a boxplot of each petal and sepal measurements

f = plt.figure(figsize=(10, 8))

sns.boxplot(data=plot_data, x='measurement', y='size', hue='species')
# Out:
# <Axes: xlabel='measurement', ylabel='size'>

# %% [markdown]
# ### Q-10

# %% [markdown]
# Pairplot

# %%
# Make a pairplot with seaborn
# to examine the correlation between each pair of measurements

# work with the original data `data`
sns.pairplot(data, hue='species')
