# %% [markdown]
# # Gradient Descent Regularization

# %%
import pandas as pd

data = pd.read_csv('../data/weight-height.csv')

# %%
data.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
data.describe()
# Out:
#              Height        Weight
# count  10000.000000  10000.000000
# mean      66.367560    161.440357
# std        3.847528     32.108439
# min       54.263133     64.700127
# 25%       63.505620    135.818051
# 50%       66.318070    161.212928
# 75%       69.174262    187.169525
# max       78.998742    269.989699

# %%
import numpy as np
import pandas as pd

height = data['Height'][data['Gender'] == 'Male'].tolist()
weight = data['Weight'][data['Gender'] == 'Male'].tolist()

X = (weight-np.mean(weight))/np.std(weight)
y = (height-np.mean(height))/np.std(height)

# %% [markdown]
# Explicit minimization
#
# `phase_1 = np.matmul(X.reshape(-1,1),X.reshape(1,-1))`
#
# Use pseudo-inverse to avoid singularities
#
# `phase_2 = np.linalg.pinv(phase_1)`
# `phase_3 = np.matmul(phase_2,X.reshape(-1,1))`
#
# `W_opt = np.matmul(y.reshape(1,-1),phase_3) `

# %%
#try the closed form formula
# don't take all the data: heavy computations !!!
X_=X[:1000]
y_=y[:1000]
y_=y_.reshape(1,-1)
X_=X_.reshape(1,-1)

w=np.matmul(X_.T,X_)
w = np.linalg.pinv(w)

w = np.matmul(w,X_.T)

w = np.matmul(y_,w)
print(w)
# Out:
# [[0.84539671]]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Initialization
W = 0
b = 0
L = 0.9 # The learning Rate
epochs = 40  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

b_ = []
W_ = []
# Performing Gradient Descent
for i in range(epochs):
    y_pred = W*X + b  # The current predicted value of Y
    D_W = (-2/n) * sum(X * (y - y_pred))  # Derivative wrt W
    D_b = (-2/n) * sum(y - y_pred)  # Derivative wrt b
    W = W - L * D_W  # Update W
    b = b - L * D_b  # Update b
    W_.append(W)
    b_.append(b)
print('W = ',W, ';b = ',b)
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Weight and bias convergence')
ax1.plot(W_)
ax2.plot(b_,'r')
# Out:
# W =  0.8628641390517823 ;b =  9.01558827592909e-16

# %%
from IPython.display import Image
rate = ['LMS.gif','LMS_0.1.gif','LMS_0.99.gif']
Image(open('/content/gdrive/MyDrive/Machon Lev/ML_5782/Course_materials/Intel-ML101-Class4/data/plots/gradient_descent/'+rate[2], 'rb').read())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 3
#       1 from IPython.display import Image
#       2 rate = ['LMS.gif','LMS_0.1.gif','LMS_0.99.gif']
# ----> 3 Image(open('/content/gdrive/MyDrive/Machon Lev/ML_5782/Course_materials/Intel-ML101-Class4/data/plots/gradient_descent/'+rate[2], 'rb').read())
#
# File \\eltiengdesc1.elta.co.il\users$\Dali0706\Desktop\repos\msc_courses\machine_learning_msc_course\.venv\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/MyDrive/Machon Lev/ML_5782/Course_materials/Intel-ML101-Class4/data/plots/gradient_descent/LMS_0.99.gif'

# %% [markdown]
# #Sort y (for better visualization) and plot the corresponding predictions

# %%
y_sort = np.sort(y)
y_idx = np.argsort(y)
plt.plot(y_pred[y_idx],color='blue', markersize=1)
plt.plot(y_sort,color='red', markersize=1)
np.corrcoef(y,y_pred)
# Out:
# array([[1.        , 0.86297885],
#        [0.86297885, 1.        ]])

# %% [markdown]
# #Calculate mse, the average prediction error

# %%
y_pred = W*X + b
mse = np.mean(np.square(y_pred-y))
print(mse)
# Out:
# 0.25526751999913916

# %%
#mse per epoch
mse_ = []
for w in W_:
    y_pred = w*X + b
    mse_.append(np.mean(np.square(y_pred-y)))
plt.plot(mse_)

# %% [markdown]
# Now using minibatch

# %%
# Stochastic (minibatch)
# general rule is “bigger batch (more confidence in the direction) size bigger learning rate”
#################
# Initialization
W = 0
b = 0
L = 0.01 # The learning Rate
epochs = 1000  # The number of iterations to perform gradient descent

n = 1 # minibatch_size

b_ = []
W_ = []
# Performing Gradient Descent
for i in range(epochs):
    #choose a few examples from X in each epoch
    idx = np.random.randint(len(X),size=n) 
    y_pred = W*X[idx] + b  # The current predicted value of Y
    D_W = (-2/n) * np.sum(X[idx] * (y[idx] - y_pred))  # Derivative wrt W
    D_b = (-2/n) * np.sum(y[idx] - y_pred)  # Derivative wrt b
    W = W - L * D_W  # Update W
    b = b - L * D_b  # Update b
    W_.append(W)
    b_.append(b)
print(W,b)
fig, (ax1, ax2) = plt.subplots(1, 2)
fig.suptitle('Weight and bias convergence')
ax1.plot(W_)
ax2.plot(b_,'r')
# Out:
# 0.9372962982502363 -0.13312677705768625

# %%
mse_ = []
for w in W_:
    y_pred = w*X + b
    mse_.append(np.mean(np.square(y_pred-y)))
plt.plot(mse_)

# %% [markdown]
# #Compare with the bultin LinearRegression function

# %%
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X.reshape(-1,1), y.reshape(-1,1))
print( lin_reg.coef_,lin_reg.intercept_)

#lin_reg.predict(X_new)
# Out:
# [[0.86297885]] [9.91855601e-16]

# %% [markdown]
# Regularization "limits" the model optimization and is useful in noise

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import linear_model

X_train = np.c_[.5, 1].T
y_train = [.5, 1]
X_test = np.c_[0, 2].T

np.random.seed(0)

classifiers = dict(ols=linear_model.LinearRegression(),
                   ridge=linear_model.Ridge(alpha=.1))

for name, clf in classifiers.items():
    fig, ax = plt.subplots(figsize=(4, 3))

    #grey - noisy models
    for _ in range(6):
        this_X = .1 * np.random.normal(size=(2, 1)) + X_train
        clf.fit(this_X, y_train)

        ax.plot(X_test, clf.predict(X_test), color='gray')
        ax.scatter(this_X, y_train, s=3, c='gray', marker='o', zorder=10)

    #blue - clean model
    clf.fit(X_train, y_train)
    ax.plot(X_test, clf.predict(X_test), linewidth=2, color='blue')
    ax.scatter(X_train, y_train, s=30, c='red', marker='+', zorder=10)

    ax.set_title(name)
    ax.set_xlim(0, 2)
    ax.set_ylim((0, 1.6))
    ax.set_xlabel('X')
    ax.set_ylabel('y')

    fig.tight_layout()

plt.show()

#without reg. models try to get the optimum weights - more variance
#reg. models predictions are biased but with less variance

# %% [markdown]
# ### Gradient descent code including regularization (L2) term in loss

# %%
#Gradient descent with or without L2 regularization
def GD_reg(X,Y,alpha):#L2
    # Initialization
    W = 0
    b = 0
    L = 0.5 # The learning Rate
    epochs = 100  # The number of iterations to perform gradient descent

    n = float(len(X)) # Number of elements in X

    b_ = []
    W_ = []
    # Performing Gradient Descent
    for i in range(epochs):
        Y_pred = W*X + b  # The current predicted value of Y
        D_W = (-2/n) * sum(X * (Y - Y_pred)) + 2*alpha*W # Derivative wrt W. Note the regularization (L2) term
        D_b = (-2/n) * sum(Y - Y_pred)  # Derivative wrt b. We don't apply regularization to intercept term
        W = W - L * D_W  # Update W
        b = b - L * D_b  # Update b
        W_.append(W)
        b_.append(b)
    return W_,b_

# %% [markdown]
# # Question 1
#
# Run the height-weight regression using SGD with regularization. Did it converge to same weight as above? Compare our function with sklearn's Ridge function.

# %%
# use the SGD with regularization

alpha = 0.1

# run our SGD with L2
W_list, b_list = GD_reg(X, y, alpha)
W_sgd, b_sgd = W_list[-1], b_list[-1]
print("SGD+L2 final W, b:", W_sgd, b_sgd)

# sklearn Ridge (compare)
ridge = linear_model.Ridge(alpha=alpha)
ridge.fit(X.reshape(-1,1), y.reshape(-1,1))
w_ridge = ridge.coef_.ravel()[0]
b_ridge = ridge.intercept_[0]
print("sklearn Ridge coef, intercept:", w_ridge, b_ridge)

# ordinary least squares for reference
ols = LinearRegression()
ols.fit(X.reshape(-1,1), y.reshape(-1,1))
w_ols = ols.coef_.ravel()[0]
b_ols = ols.intercept_[0]
print("OLS coef, intercept:", w_ols, b_ols)

# compute and print MSEs
y_pred_sgd = W_sgd * X + b_sgd
y_pred_ridge = ridge.predict(X.reshape(-1,1)).ravel()
y_pred_ols = ols.predict(X.reshape(-1,1)).ravel()

print("MSE SGD+L2:", np.mean((y - y_pred_sgd)**2))
print("MSE Ridge:", np.mean((y - y_pred_ridge)**2))
print("MSE OLS:", np.mean((y - y_pred_ols)**2))

# short conclusion printed
print("\nConclusion: Ridge and SGD+L2 should be close (not identical) due to optimization/learning-rate settings.")
# Out:
# SGD+L2 final W, b: 0.7845262260148339 1.039079933207176e-15
# sklearn Ridge coef, intercept: 0.86296158938453 9.918658412743165e-16
# OLS coef, intercept: 0.8629788486163176 9.918556013171375e-16
# MSE SGD+L2: 0.26142232083390576
# MSE Ridge: 0.2552675071387361
# MSE OLS: 0.25526750684085503
#
# Conclusion: Ridge and SGD+L2 should be close (not identical) due to optimization/learning-rate settings.
